# %% [markdown]
# <a href="https://colab.research.google.com/github/aashishneupane87-sketch/CampusX/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Aashish')
# Out:
# Aashish

# %% [markdown]
# # push to github

# %%
#this is where my code will be saved to the github
